# %% [markdown]
# ## 🔎 Missing Value Identification.

# %% [markdown]
# #### Dataset Loading and Null Check

# %%
import pandas as pd

df = pd.read_csv('data/iris_dataset.csv')

print(df.head())

missing_counts = df.isnull().sum()
missing_pct = (missing_counts / len(df)) * 100
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#         target
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# #### Missing Value Summary

# %%
missing_summary = pd.DataFrame({
    'Column Name': df.columns,
    'Data Type': df.dtypes.astype(str),
    'Missing Count': missing_counts, 
    'Missing Percentage': missing_pct,
    'Total Rows': len(df)
})

print("--- MISSING VALUE SUMMARY ---")
print(missing_summary)
print(f"\nTotal rows in dataset: {len(df)}")
print(
    f"Columns with missing data: {missing_summary[missing_summary['Missing Count'] > 0]['Column Name'].tolist() or 'None'}"
)
# Out:
# --- MISSING VALUE SUMMARY ---
#                          Column Name Data Type  Missing Count  \
# sepal length (cm)  sepal length (cm)   float64              0
# sepal width (cm)    sepal width (cm)   float64              0
# petal length (cm)  petal length (cm)   float64              0
# petal width (cm)    petal width (cm)   float64              0
# target                        target    object              0
#
#                    Missing Percentage  Total Rows
# sepal length (cm)                 0.0         150
# sepal width (cm)                  0.0         150
# petal length (cm)                 0.0         150
# petal width (cm)                  0.0         150
# target                            0.0         150
#
# Total rows in dataset: 150
# Columns with missing data: None
